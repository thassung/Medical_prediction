# %%
#importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,classification_report

# %%
df = pd.read_csv('D:\AIT\Sem 1\Machine Learning\Medical_prediction\Medical_prediction\data\insurance.csv')

# %%
df.shape
# Out:
# (1338, 7)

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
# Visualize box plots for numerical columns 
df.boxplot(column=['age', 'bmi', 'children', 'charges']) 
plt.title('Box plot of Numerical Columns')
plt.show()

# %%
# Handling outliers
# Remove outliers based on a specific threshold
df_cleaned = df[(df['charges'] < 21000) & (df['bmi'] < 46)]

# %%
# visualize boxplot after removing outliers
df_cleaned.boxplot(column=['age', 'bmi', 'children', 'charges'])
plt.title('Box plot of Numerical Columns')
plt.show()

# %%
sns.set(style='whitegrid')
f, ax = plt.subplots(1,1, figsize=(12, 8))
ax = sns.distplot(df_cleaned['charges'], kde = True, color = 'c')
plt.title('Distribution of Charges')
plt.show()
# Out:
# C:\Users\LEGION\AppData\Local\Temp\ipykernel_29268\3950684346.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(df['charges'], kde = True, color = 'c')

# %%
f, ax = plt.subplots(1, 1, figsize=(12, 8))
ax = sns.distplot(np.log10(df_cleaned['charges']), kde = True, color = 'r' )
plt.show()
# Out:
# C:\Users\LEGION\AppData\Local\Temp\ipykernel_29268\449780374.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(np.log10(df['charges']), kde = True, color = 'r' )

# %%
charges = df_cleaned['charges'].groupby(df.region).sum().sort_values(ascending = True)
f, ax = plt.subplots(1, 1, figsize=(8, 6))
ax = sns.barplot(x= charges.head(), y=charges.head().index, palette='Blues')
plt.show()

# %%
df_cleaned.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
styled_data = (
    df_cleaned.describe()
    .drop("count", axis=0)
    .style.background_gradient(axis=0, cmap="magma")
    .set_properties(**{"text-align": "center"})
    .set_table_styles([{"selector": "th", "props": [("background-color", "k")]}])
    .set_caption("Summary Statistics")
)

styled_data
# Out:
# <style type="text/css">
# #T_addbe th {
#   background-color: k;
# }
# #T_addbe_row0_col0 {
#   background-color: #b0357b;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_addbe_row0_col1 {
#   background-color: #df4a68;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_addbe_row0_col2 {
#   background-color: #420f75;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_addbe_row0_col3 {
#   background-color: #792282;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_addbe_row1_col0, #T_addbe_row1_col1, #T_addbe_row2_col2, #T_addbe_row2_col3, #T_addbe_row3_col2 {
#   background-color: #000004;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_addbe_row1_col2 {
#   background-color: #4e117b;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_addbe_row1_col3 {
#   background-color: #38106c;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_addbe_row2_col0 {
#   background-color: #0e0b2b;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_addbe_row2_col1 {
#   background-color: #51127c;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_addbe_row3_col0 {
#   background-color: #4c117a;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_addbe_row3_col1 {
#   background-color: #b5367a;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_addbe_row3_col3 {
#   background-color: #241253;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_addbe_row4_col0 {
#   background-color: #ae347b;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_addbe_row4_col1 {
#   background-color: #de4968;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_addbe_row4_col2 {
#   background-color: #3b0f70;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_addbe_row4_col3 {
#   background-color: #6b1d81;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_addbe_row5_col0 {
#   background-color: #f9795d;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_addbe_row5_col1 {
#   background-color: #f7705c;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_addbe_row5_col2 {
#   background-color: #8c2981;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_addbe_row5_col3 {
#   background-color: #c03a76;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_addbe_row6_col0, #T_addbe_row6_col1, #T_addbe_row6_col2, #T_addbe_row6_col3 {
#   background-color: #fcfdbf;
#   color: #000000;
#   text-align: center;
# }
# </style>
# <table id="T_addbe">
#   <caption>Summary Statistics</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_addbe_level0_col0" class="col_heading level0 col0" >age</th>
#       <th id="T_addbe_level0_col1" class="col_heading level0 col1" >bmi</th>
#       <th id="T_addbe_level0_col2" class="col_heading level0 col2" >children</th>
#       <th id="T_addbe_level0_col3" class="col_heading level0 col3" >charges</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_addbe_level0_row0" class="row_heading level0 row0" >mean</th>
#       <td id="T_addbe_row0_col0" class="data row0 col0" >38.353601</td>
#       <td id="T_addbe_row0_col1" class="data row0 col1" >30.092376</td>
#       <td id="T_addbe_row0_col2" class="data row0 col2" >1.075772</td>
#       <td id="T_addbe_row0_col3" class="data row0 col3" >8153.051666</td>
#     </tr>
#     <tr>
#       <th id="T_addbe_level0_row1" class="row_heading level0 row1" >std</th>
#       <td id="T_addbe_row1_col0" class="data row1 col0" >13.949224</td>
#       <td id="T_addbe_row1_col1" class="data row1 col1" >5.853846</td>
#       <td id="T_addbe_row1_col2" class="data row1 col2" >1.221247</td>
#       <td id="T_addbe_row1_col3" class="data row1 col3" >4931.368671</td>
#     </tr>
#     <tr>
#       <th id="T_addbe_level0_row2" class="row_heading level0 row2" >min</th>
#       <td id="T_addbe_row2_col0" class="data row2 col0" >18.000000</td>
#       <td id="T_addbe_row2_col1" class="data row2 col1" >15.960000</td>
#       <td id="T_addbe_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_addbe_row2_col3" class="data row2 col3" >1121.873900</td>
#     </tr>
#     <tr>
#       <th id="T_addbe_level0_row3" class="row_heading level0 row3" >25%</th>
#       <td id="T_addbe_row3_col0" class="data row3 col0" >26.000000</td>
#       <td id="T_addbe_row3_col1" class="data row3 col1" >25.840000</td>
#       <td id="T_addbe_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_addbe_row3_col3" class="data row3 col3" >4032.240700</td>
#     </tr>
#     <tr>
#       <th id="T_addbe_level0_row4" class="row_heading level0 row4" >50%</th>
#       <td id="T_addbe_row4_col0" class="data row4 col0" >38.000000</td>
#       <td id="T_addbe_row4_col1" class="data row4 col1" >29.830000</td>
#       <td id="T_addbe_row4_col2" class="data row4 col2" >1.000000</td>
#       <td id="T_addbe_row4_col3" class="data row4 col3" >7441.053000</td>
#     </tr>
#     <tr>
#       <th id="T_addbe_level0_row5" class="row_heading level0 row5" >75%</th>
#       <td id="T_addbe_row5_col0" class="data row5 col0" >50.000000</td>
#       <td id="T_addbe_row5_col1" class="data row5 col1" >33.915000</td>
#       <td id="T_addbe_row5_col2" class="data row5 col2" >2.000000</td>
#       <td id="T_addbe_row5_col3" class="data row5 col3" >11534.872650</td>
#     </tr>
#     <tr>
#       <th id="T_addbe_level0_row6" class="row_heading level0 row6" >max</th>
#       <td id="T_addbe_row6_col0" class="data row6 col0" >64.000000</td>
#       <td id="T_addbe_row6_col1" class="data row6 col1" >45.900000</td>
#       <td id="T_addbe_row6_col2" class="data row6 col2" >5.000000</td>
#       <td id="T_addbe_row6_col3" class="data row6 col3" >20984.093600</td>
#     </tr>
#   </tbody>
# </table>

# %%
smokers_by_region = df_cleaned.groupby('region')['smoker'].value_counts().unstack().fillna(0)
smokers_by_region.plot(kind='barh')
plt.xlabel('Count')
plt.ylabel('Region')
plt.title('Count of Smokers by Region')
plt.legend(title='Smoker', loc='upper right')
plt.show()

# %%
smoker_counts = df_cleaned['smoker'].value_counts() 
plt.pie(smoker_counts, labels=smoker_counts.index, autopct='%1.1f%%') 
plt.title('Distribution of Smokers')
plt.show()

# %%
sns.violinplot(x=df_cleaned['children'], y=df_cleaned['charges'])

plt.xlabel('Number of Children')
plt.ylabel('Charges')

plt.title('Charges by Number of Children')
plt.show()

# %%
sns.countplot(x='sex', data=df_cleaned)
plt.xlabel('Sex')
plt.ylabel('Count')
plt.title('Distribution of Sex')
plt.show()

# %%
# distribution of age using histogram
df_cleaned['age'].plot(kind='hist', bins=20)

plt.xlabel('Age')
plt.title('Distribution of Age')

plt.show()

# %%
# distribution of BMI using histogram
df_cleaned['bmi'].plot(kind='hist', bins=20, color='r')
plt.xlabel('BMI')
plt.title('Distribution of BMI')
plt.show()

# %%
# relationship between age and charges using scatterplot
df_cleaned.plot(kind='scatter', x='age', y='charges', color='g')
plt.xlabel('Age')
plt.ylabel('Charges')
plt.title('Relationship between Age and Charges')
plt.show()

# %% [markdown]
# There is a linearly increasing relationship between age and insurance charges. Older people are tend to be charged more

# %%
number_columns = df_cleaned.select_dtypes("number").drop("charges", axis=1)

skewness_before_log = df_cleaned[number_columns.columns].skew()
fig, axes = plt.subplots(
    nrows=3,
    ncols=3,
    figsize=(9, 11),
    gridspec_kw={"hspace": 0.35, "wspace": 0.3, "width_ratios": [0.5, 0.3, 0.3]},
)
axes = axes.flatten()
i = 0
for column in number_columns.columns:
    ax = axes[i]
    sns.regplot(
        data=df_cleaned,
        x=column,
        y="charges",
        ax=ax,
        scatter_kws={"alpha": 0.5},
        marker="o",
        line_kws={"color": "orange"},
        order=3,
    )
    ax.set_title(f"{column} vs charges", size=9)
    ax = axes[i + 1]
    sns.kdeplot(data=df_cleaned, x=column, ax=ax, fill=False, alpha=0.9, legend=True)
    skewness = skewness_before_log[column]
    ax.text(
        ax.get_xlim()[0],
        ax.get_ylim()[-1],
        f"skew: {skewness:.2f}",
        size=9,
        weight="bold",
    )

    ax = axes[i + 2]
    sns.boxplot(
        data=df_cleaned,
        y=column,
        ax=ax,
        width=0.6,
        saturation=0.9,
        linewidth=0.9,
    )
    i += 3
plt.show()
